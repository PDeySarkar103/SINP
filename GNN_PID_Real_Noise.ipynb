# %% [markdown]
# # Particle Identification using GNN on HGCAL dataset- Realistic noise

# %% [markdown]
# We have already done the following:
# 1. Added a Gaussian Noise.
# 2. We had done the normalization per hit per layer. This had completely removed the longitudinal profile information. We only had the lateral profile- per layer relative energy at each hit cell, with respect to the hit cell with maximum energy deposit in that particular layer
# 3. We added the longitudinal profile information manually using the *layer profile*, which is the normalized tensor, representing the per event relative total energy in each layer, with respect to the layer with maximum total hit energy.
# 4. We had developed a more **intense** architecture.

# %% [markdown]
# Now, we will try to add a realistic noise, which is an energy dependent noise, as seen in most of the calorimeters in modern times. The calorimeter resolution in general is:\
# $
# \frac{\sigma_E}{E}= \frac{S}{\sqrt{E}}\oplus\frac{N}{E}\oplus C
# $
# where, $\rightarrow$Stochastic term, N$\rightarrow$Noise term, C$\rightarrow$Constant term, $\oplus \rightarrow$ added in quadrature. \
# We can further simplify for each hit cell as \
# $
# \frac{\sigma(E)}{E}=\frac{a}{\sqrt{E}}\oplus b
# $ \
# or
# $
# \sigma(E)=\sqrt{(a^2E)+b^2}
# $ \
# where,\
# a$\rightarrow$Stochastic coefficient\
# b$\rightarrow$ electronic noise term.

# %% [markdown]
# ## Importing the required packages

# %%
#General packages
import uproot
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt

#Torch packages
import torch
import torch.nn as nn
import torch.nn.functional as F

#Packages for GNN
from torch_geometric.data import Data, Dataset
from torch_geometric.loader import DataLoader
#from torch_geometric.nn import GCNConv, global_add_pool
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# ## ROOT ---> Numpy arrays

# %%
#file=uproot.open("ntuple_pi+_100GeV_100keve.root:AllLayers")
#branches=["hit_x","hit_y","hit_z","hit_l","hit_E"]
#events=file.arrays(branches,library="ak")

# %%
#events  ### Awkawrd array in Dictionary like format
#type(events)
#events.hit_x # Returns the awkard arrays for the hit_x for all events

# %%
#events[0].hit_x # Returns the hit_x data for the first event, as numpy arrays

# %% [markdown]
# ## Preparing the Dataset

# %%
#Defining the root files and their path names
particle_files={
    "pi+":"ntuple_pi+_100GeV_100keve.root:AllLayers",
    "e+":"ntuple_e+_100_GeV_100Keve.root:AllLayers",
    "Y":"ntuple_gamma_100GeV_25keve_p1.root:AllLayers",
    "K-":"ntuple_kaon-_100GeV_20keve_p1.root:AllLayers",
    "K+":"ntuple_kaon+_100GeV_20keve_p1.root:AllLayers",
    "K_0":"ntuple_kaon0L_100GeV_10keve_test.root:AllLayers",
    "mu+":"ntuple_mu+_100GeV_100keve.root:AllLayers",
    "n":"ntuple_neutron_100GeV_10keve_test.root:AllLayers",
    "p":"ntuple_proton_100GeV_20keve_p1.root:AllLayers"
}
particle_ids={
    "pi+":0,
    "e+":1,
    "Y":2,
    "K-":3,
    "K+":4,
    "K_0":5,
    "mu+":6,
    "n":7,
    "p":8
}

# %%
#Defining the root files and their path names
particle_files={
    "pi+":"ntuple_pi+_100GeV_100keve.root:AllLayers",
    "e+":"ntuple_e+_100_GeV_100Keve.root:AllLayers",
    "Y":"ntuple_gamma_100GeV_25keve_p1.root:AllLayers",
    
}
particle_ids={
    "pi+":0,
    "e+":1,
    "Y":2
}

# %%
branches=["hit_x","hit_y","hit_z","hit_l","hit_E"]
all_events=[]
all_labels=[]

for pname,file_path in particle_files.items():
    file=uproot.open(file_path)
    events=file.arrays(branches,library="ak")[:5000] #Only 5000 events for now
    #Assigning particle ids
    pid=particle_ids[pname]
    #Store everything as a tuple
    all_events.extend([(events[i],pid) for i in range(len(events))])

# %%
#Shuffling
from sklearn.utils import shuffle
all_events=shuffle(all_events,random_state=28)

# %%
all_events[0][0]
# Out:
# <Record {hit_x: [0, ...], hit_y: [...], ...} type='{hit_x: var * float64, h...'>

# %%
all_events[0][1]
# Out:
# 0

# %%
all_events[4][1]
# Out:
# 1

# %%
np.sum(all_events[0][0].hit_E)
# Out:
# 0.26254437455448687

# %%
np.sum(all_events[0][0].hit_E)
# Out:
# 0.26254437455448687

# %% [markdown]
# ## Adding Noise

# %% [markdown]
# Now, we will try to add a realistic noise, which is an energy dependent noise, as seen in most of the calorimeters in modern times. The calorimeter resolution in general is:\
# $
# \frac{\sigma_E}{E}= \frac{S}{\sqrt{E}}\oplus\frac{N}{E}\oplus C
# $
# where, $\rightarrow$Stochastic term, N$\rightarrow$Noise term, C$\rightarrow$Constant term, $\oplus \rightarrow$ added in quadrature. \
# We can further simplify for each hit cell as \
# $
# \frac{\sigma(E)}{E}=\frac{a}{\sqrt{E}}\oplus b
# $ \
# or
# $
# \sigma(E)=\sqrt{(a^2E)+b^2}
# $ \
# where,\
# a$\rightarrow$Stochastic coefficient\
# b$\rightarrow$ electronic noise term.
#
# The final energy in each hit cell is then, \
# $E_{total}=Signal+N(\mu,\sigma(E))$,\
# where, $N(\mu,\sigma(E))$ is the Gausian distributed noise, with a mean $\mu$ and the standard deviation being $\sigma(E)$, which is the energy dependent standard deviation

# %%
def add_HGCAL_noise(event,noise_mean,a=0.2,b=0.05,threshold_sigma=None,random_state=None):
    signal=np.array(event.hit_E)
    #Computing the sigma
    sigma=np.sqrt((a**2)*signal + b**2)
    #Compute the Gaussian noise, with this sigma
    noise=np.random.normal(loc=0.0,scale=sigma,size=np.size(signal))
    E_noisy=signal+noise
    #Clipping zero and negative energies
    E_noisy[E_noisy<=0]=0.0
    #Optional zero suppression- based on threshold
    if threshold_sigma is not None:
        threshold=threshold_sigma*b
        E_noisy[E_noisy<threshold]=0.0
    #Newly record the data
    event_noisy=ak.Record(
    {
        "hit_x":event.hit_x,
        "hit_y":event.hit_y,
        "hit_z":event.hit_z,
        "hit_l":event.hit_l,
        "hit_E":E_noisy
    })
    
    return event_noisy

# %%
np.random.seed(42) #For explaining reproductivity
all_events_noisy=[]
noise_mean=0.0
#noise_std=0.03

for event,pid in all_events:
    event_noisy=add_HGCAL_noise(event,noise_mean=noise_mean)
    all_events_noisy.append((event_noisy,pid))

# %%
all_events_noisy[0][0]
# Out:
# <Record {hit_x: [0, ...], hit_y: [...], ...} type='{hit_x: 526 * float64, h...'>

# %% [markdown]
# ## Longitudinal profile- Layer Energy Profile

# %%
def layer_profile(event,global_max_layers=50):
    layers=ak.to_numpy(event.hit_l)
    layers=torch.tensor(layers)
    energies=ak.to_numpy(event.hit_E)
    energies=torch.tensor(energies)
    layer_sums=torch.bincount(input=layers-1,weights=energies,minlength=global_max_layers)
    #Maximum energy
    max_energy=layer_sums.max()
    if max_energy>0:
        layer_sums_norm=layer_sums/max_energy
    #return torch.tensor(layer_sums_norm,dtype=torch.float64)
    layer_sums_norm=torch.unsqueeze(layer_sums_norm,0)
    return layer_sums_norm

# %%
#Test
layer_profile(all_events_noisy[4][0]).shape
# Out:
# torch.Size([1, 50])

# %%
#layer_profile(all_events_noisy[5][0])

# %%
#A=torch.tensor([1,2,3])
#B=torch.unsqueeze(A,0)
#B.shape
#A.unsqueeze(0)
#print(A.shape)

# %% [markdown]
# ## Lateral Profile- Average energy per hits per layer

# %%
def normalize_hits_by_layer(event):
    layer=ak.to_numpy(event.hit_l)
    energy=ak.to_numpy(event.hit_E)
    #Prepare an array to store normalized energies
    energy_norm=np.zeros_like(energy)
    #Finding unique layers
    unique_layer=np.unique(layer)
    for l in unique_layer:
        #Extract the inndices of the hits in this layer
        mask=layer==l
        if np.any(mask):
            max_energy=energy[mask].max()
            if max_energy>0:
                energy_norm[mask]=energy[mask]/max_energy
            elif max_energy==0:
                energy_norm[mask]=0.0
    #Rebuild the record
    event_norm=ak.Record({
        "hit_x":event.hit_x,
        "hit_y":event.hit_y,
        "hit_z":event.hit_z,
        "hit_l":event.hit_l,
        "hit_E":energy_norm
    })
    return event_norm

# %%
all_events_normalized=[]
for event,pid in all_events_noisy:
    event_norm=normalize_hits_by_layer(event)
    all_events_normalized.append((event_norm,pid))

# %% [markdown]
# ## Creating the event graphs

# %%
def create_graph(event,k=8):
    x=ak.to_numpy(event.hit_x)
    y=ak.to_numpy(event.hit_y)
    z=ak.to_numpy(event.hit_z)
    l=ak.to_numpy(event.hit_l)
    E=ak.to_numpy(event.hit_E)
    #Removing zero energy hits
    mask_E=E>0
    x,y,z,l,E=x[mask_E],y[mask_E],z[mask_E],l[mask_E],E[mask_E]
    coords=np.column_stack((x,y,z))
    N=len(coords)
    if N<k+1:
        return None
    
    #Node features
    node_features=torch.from_numpy(np.column_stack((x,y,z,l,E))).float()

    #Global KNN
    knn=NearestNeighbors(n_neighbors=k+1,algorithm="kd_tree").fit(coords)
    knn_dist,knn_idx=knn.kneighbors(coords)
    knn_idx=knn_idx[:,1:] #Removes the self hit
    #print(knn_dist[9,:],knn_idx[9,:])

    #Edge construction
    src=np.repeat(np.arange(N),k)
    dst=knn_idx.reshape(-1)
    mask=dst>=0
    src,dst=src[mask],dst[mask]
    edge_index=torch.tensor(np.vstack([src,dst]),dtype=torch.long)

    #Edge attributes
    edge_attr = torch.tensor((E[src] * E[dst]).reshape(-1, 1),dtype=torch.float)

    #Final creation
    graph= Data(x=node_features,edge_index=edge_index,edge_attr=edge_attr)
    return graph

# %%
#graph=[create_graph(event,k=8) for event in events]

# %%
#creating graphs for all events
graph=[]
for event,pid in all_events_noisy:
    g=create_graph(event,k=8)
    profile=layer_profile(event,global_max_layers=50)
    if g is not None:
        g.y=torch.tensor([pid],dtype=torch.long)
        g.layer_profile=profile
        graph.append(g)

# %%
graph[0]
# Out:
# Data(x=[265, 5], edge_index=[2, 2120], edge_attr=[2120, 1], y=[1], layer_profile=[1, 50])

# %%
#Debugging-1
#for g in graph[:20]:
#    print(g.y.item())

# %%
#Debugging-2
#g = graph[3]
#print(g.y)
#print(g.y.shape)

# %%
#Test-1
graph[:20]
# Out:
# [Data(x=[265, 5], edge_index=[2, 2120], edge_attr=[2120, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[72, 5], edge_index=[2, 576], edge_attr=[576, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[383, 5], edge_index=[2, 3064], edge_attr=[3064, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[382, 5], edge_index=[2, 3056], edge_attr=[3056, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[361, 5], edge_index=[2, 2888], edge_attr=[2888, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[364, 5], edge_index=[2, 2912], edge_attr=[2912, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[367, 5], edge_index=[2, 2936], edge_attr=[2936, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[365, 5], edge_index=[2, 2920], edge_attr=[2920, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[354, 5], edge_index=[2, 2832], edge_attr=[2832, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[344, 5], edge_index=[2, 2752], edge_attr=[2752, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[321, 5], edge_index=[2, 2568], edge_attr=[2568, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[99, 5], edge_index=[2, 792], edge_attr=[792, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[366, 5], edge_index=[2, 2928], edge_attr=[2928, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[294, 5], edge_index=[2, 2352], edge_attr=[2352, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[358, 5], edge_index=[2, 2864], edge_attr=[2864, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[117, 5], edge_index=[2, 936], edge_attr=[936, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[383, 5], edge_index=[2, 3064], edge_attr=[3064, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[211, 5], edge_index=[2, 1688], edge_attr=[1688, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[360, 5], edge_index=[2, 2880], edge_attr=[2880, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[349, 5], edge_index=[2, 2792], edge_attr=[2792, 1], y=[1], layer_profile=[1, 50])]

# %%
#Test-2
graph[2].layer_profile
# Out:
# tensor([[0.0000, 0.0000, 0.1560, 0.1350, 0.1414, 0.4569, 0.5402, 0.3826, 0.6989,
#          0.9935, 0.7119, 0.5813, 1.0000, 0.5810, 0.7259, 0.8394, 0.2732, 0.6334,
#          0.3176, 0.3979, 0.1998, 0.2021, 0.1296, 0.0629, 0.0240, 0.0966, 0.0838,
#          0.0000, 0.0605, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000]], dtype=torch.float64)

# %% [markdown]
# ## Splitting into training and testing

# %%
from sklearn.model_selection import train_test_split

#First split: Train vs Temp(Val+Test)
train_data, temp_data= train_test_split(graph, test_size=0.3, random_state=42)

#Second split: Test vs Val
val_data, test_data= train_test_split(temp_data, test_size=0.7, random_state=42)

print(f"Training samples: {len(train_data)}")
print(f"Validation samples: {len(val_data)}")
print(f"Test samples: {len(test_data)}")
# Out:
# Training samples: 10500
# Validation samples: 1350
# Test samples: 3150

# %%
#graph[:64]

# %% [markdown]
# ## Using DataLoader

# %%
from torch_geometric.loader import DataLoader
batch_size=64

train_loader=DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader=DataLoader(val_data, batch_size=batch_size, shuffle=True)
test_loader=DataLoader(test_data, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## Computing layer profile for events in each batch

# %%
#Computing the layer_profile per graph
#def

# %%
def layer_profile_batchwise(batch,global_max_layers=50):
    profiles=[]
    for graph in batch.to_data_list():
        profile=layer_profile(graph,global_max_layers=global_max_layers)
        profiles.append(profile)
    profiles=torch.stack(profiles,dim=1)
    return profiles.float()

# %% [markdown]
# ## Making the GCN

# %% [markdown]
# ### Developing the Message Passing Block

# %%
#Making the message passing network
import torch
from torch.nn import Linear, Parameter
from torch_geometric.nn import MessagePassing
from torch_geometric.utils import add_self_loops, degree
class GCNConv(MessagePassing):
    def __init__(self,in_channels,out_channels):
        #Here, in_channels: Input node features
        super().__init__(aggr='add')
        self.lin=Linear(in_channels,out_channels,bias=False)
        self.bias = Parameter(torch.Tensor(out_channels))
        self.reset_parameters()
        
    def reset_parameters(self):
        self.lin.reset_parameters()
        self.bias.data.zero_()
        
    def forward(self,x,edge_index):
        # x has the shape [No. of hits, in_channels]
        #edge_index has shape [2, No. of edges]
        #Step-1: Add self loops
        edge_index,_=add_self_loops(edge_index,num_nodes=x.size(0))
        #Step-2: Linearly transform node feature matrix
        x=self.lin(x)
        #Step-3: Compute Normalization
        row,col=edge_index
        deg=degree(col,x.size(0))
        deg_inv_sqr=deg.pow(-0.5)
        deg_inv_sqr[deg_inv_sqr==float('inf')]=0
        norm=deg_inv_sqr[row]*deg_inv_sqr[col]
        #Step-4-5: Propagating the message- Normalize the node features and then add
        out=self.propagate(edge_index,x=x,norm=norm)
        #Step 6: Apply the end bias vector
        out=out+self.bias
        
        return out
    
    def message(self, x_j, norm):
        return norm.view(-1,1)*x_j

# %% [markdown]
# ### Stacking the GNN layers for 'Convolution'

# %% [markdown]
# #### Advanced Model

# %%
import torch
from torch import nn
import torch.nn.functional as F
#from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_add_pool,BatchNorm

class GCN_Event_Classifier(nn.Module):
    def __init__(self, input_dim,hidden_dim,output_dim):
        super().__init__()
        #The GCN Layers
        ## First-layer
        self.conv1=GCNConv(input_dim,hidden_dim)
        self.bn1=BatchNorm(hidden_dim)
        ## 6 repeated blocks
        self.convs=nn.ModuleList()
        self.bns=nn.ModuleList()
        for i in range(6):
            self.convs.append(GCNConv(hidden_dim,hidden_dim))
            self.bns.append(BatchNorm(hidden_dim))
        ##Final layer
        self.final_conv=GCNConv(hidden_dim,hidden_dim)
        #Regularization
        self.dropout=nn.Dropout(p=0.1)
        
        #Output- MLP- mainly doing the classification task.
        self.output=nn.Sequential(
            nn.Linear(hidden_dim+50,hidden_dim),
            #nn.ReLU(),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim,hidden_dim),
            #nn.ReLU(),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim,output_dim)
        )
        
    def forward(self,data):
        #x,edge_index=data.x, data.edge_index
        x,edge_index,batch=data.x,data.edge_index,data.batch
        #print(data.x.shape)
        
        #-----------Graph Convolution--------------
        #####First GCN Block#######
        x=self.conv1(x,edge_index)
        x=self.bn1(x)
        x=F.relu(x)
        x=self.dropout(x)
        #### Repeated convolutions ####
        for conv,bn in zip(self.convs,self.bns):
            x=conv(x,edge_index)
            x=bn(x)
            x=F.relu(x)
            x=self.dropout(x)
        #### Final convolution ####
        x=self.final_conv(x,edge_index)
        #Saving the node embeddings
        node_embedding=x
        #print(node_embedding.shape)
        
        #Graph-level event embedding
        event_embedding=global_add_pool(x,batch) # shape: [batch_size,hidden_dim]
        #print(event_embedding.shape)
        
        #Get layer profile
        layer_profile=data.layer_profile
        #print(layer_profile.shape)
        #if layer_profile.dim()==1:
        #    layer_profile=layer_profile.unsqueeze(0)
        layer_profile=layer_profile.float()
        #layer_profile.unsqueeze(0)
        #if layer_profile.size(0)!=event_embedding.size(0):
        #    layer_profile=layer_profile.expand(event_embedding.size(0),-1)
            
        
        #layer_profile=data.layer_profile.float()
        #Combined- Concatenate the features
        combined=torch.cat([event_embedding,layer_profile],dim=1)
        #print(combined.shape)
        #Node-level-predictions
        out=self.output(combined)
        
        return out,node_embedding

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
#model=GCN_Event_Classifier(input_dim=5,hidden_dim=64,output_dim=9).to(device)
layer_dim=graph[0].layer_profile.shape[0]
model=GCN_Event_Classifier(input_dim=5,hidden_dim=25,output_dim=3).to(device)

# %%
model
# Out:
# GCN_Event_Classifier(
#   (conv1): GCNConv()
#   (bn1): BatchNorm(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (convs): ModuleList(
#     (0-5): 6 x GCNConv()
#   )
#   (bns): ModuleList(
#     (0-5): 6 x BatchNorm(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (final_conv): GCNConv()
#   (dropout): Dropout(p=0.1, inplace=False)
#   (output): Sequential(
#     (0): Linear(in_features=75, out_features=25, bias=True)
#     (1): BatchNorm1d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=25, out_features=25, bias=True)
#     (4): BatchNorm1d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Linear(in_features=25, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# ### Developing the training, validation and testing loops

# %%
optimizer=torch.optim.Adam(model.parameters(),lr=0.0001)
criterion=torch.nn.CrossEntropyLoss()

# %%
#Training loop
def train():
    model.train()
    total_loss=0.0
    for batch in train_loader:
        batch=batch.to(device)
        optimizer.zero_grad()
        #Computing batchwise layer profiles
        #profiles=layer_profile_batchwise(batch,global_max_layers=50)
        out,_=model(batch)
        loss=criterion(out,batch.y)
        #Backpropagation
        loss.backward() 
        optimizer.step()
        total_loss+=loss.item()
        
    return total_loss/len(train_loader)

# %%
#Validation loop
def validate():
    model.eval()
    total_loss=0.0
    with torch.no_grad():
        for batch in val_loader:
            batch=batch.to(device)
            out,_=model(batch)
            loss=criterion(out,batch.y)
            total_loss+=loss.item()
    return total_loss/len(val_loader)

# %%
#Running the model
#epochs=100
epochs=500
train_losses=[]
val_losses=[]
for epochs in range(1,epochs+1):
    train_loss=train()
    val_loss=validate()
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    print(f"Epoch {epochs}, Train Loss: {train_loss:.4f}, Val loss: {val_loss:.4f}")
# Out:
# Epoch 1, Train Loss: 0.8881, Val loss: 0.7292
# Epoch 2, Train Loss: 0.7354, Val loss: 0.6640
# Epoch 3, Train Loss: 0.6763, Val loss: 0.6048
# Epoch 4, Train Loss: 0.6296, Val loss: 0.5780
# Epoch 5, Train Loss: 0.5910, Val loss: 0.5386
# Epoch 6, Train Loss: 0.5632, Val loss: 0.5184
# Epoch 7, Train Loss: 0.5573, Val loss: 0.5009
# Epoch 8, Train Loss: 0.5282, Val loss: 0.4832
# Epoch 9, Train Loss: 0.5194, Val loss: 0.5023
# Epoch 10, Train Loss: 0.5042, Val loss: 0.4721
# Epoch 11, Train Loss: 0.5002, Val loss: 0.4720
# Epoch 12, Train Loss: 0.4937, Val loss: 0.4847
# Epoch 13, Train Loss: 0.4915, Val loss: 0.4684
# Epoch 14, Train Loss: 0.4915, Val loss: 0.4473
# Epoch 15, Train Loss: 0.4834, Val loss: 0.4565
# Epoch 16, Train Loss: 0.4763, Val loss: 0.4533
# Epoch 17, Train Loss: 0.4762, Val loss: 0.4385
# Epoch 18, Train Loss: 0.4745, Val loss: 0.4389
# Epoch 19, Train Loss: 0.4820, Val loss: 0.4548
# Epoch 20, Train Loss: 0.4698, Val loss: 0.4457
# Epoch 21, Train Loss: 0.4677, Val loss: 0.4523
# Epoch 22, Train Loss: 0.4642, Val loss: 0.4235
# Epoch 23, Train Loss: 0.4618, Val loss: 0.4353
# Epoch 24, Train Loss: 0.4557, Val loss: 0.4427
# Epoch 25, Train Loss: 0.4558, Val loss: 0.4388
# Epoch 26, Train Loss: 0.4574, Val loss: 0.4209
# Epoch 27, Train Loss: 0.4572, Val loss: 0.4431
# Epoch 28, Train Loss: 0.4597, Val loss: 0.4174
# Epoch 29, Train Loss: 0.4576, Val loss: 0.4237
# Epoch 30, Train Loss: 0.4555, Val loss: 0.4207
# Epoch 31, Train Loss: 0.4525, Val loss: 0.4175
# Epoch 32, Train Loss: 0.4508, Val loss: 0.4200
# Epoch 33, Train Loss: 0.4484, Val loss: 0.4273
# Epoch 34, Train Loss: 0.4480, Val loss: 0.4211
# Epoch 35, Train Loss: 0.4502, Val loss: 0.4153
# Epoch 36, Train Loss: 0.4457, Val loss: 0.4375
# Epoch 37, Train Loss: 0.4420, Val loss: 0.4268
# Epoch 38, Train Loss: 0.4456, Val loss: 0.4122
# Epoch 39, Train Loss: 0.4449, Val loss: 0.4316
# Epoch 40, Train Loss: 0.4592, Val loss: 0.4377
# Epoch 41, Train Loss: 0.4441, Val loss: 0.4228
# Epoch 42, Train Loss: 0.4508, Val loss: 0.4134
# Epoch 43, Train Loss: 0.4441, Val loss: 0.4163
# Epoch 44, Train Loss: 0.4526, Val loss: 0.4158
# Epoch 45, Train Loss: 0.4438, Val loss: 0.4265
# Epoch 46, Train Loss: 0.4433, Val loss: 0.4269
# Epoch 47, Train Loss: 0.4432, Val loss: 0.4174
# Epoch 48, Train Loss: 0.4552, Val loss: 0.4181
# Epoch 49, Train Loss: 0.4478, Val loss: 0.4211
# Epoch 50, Train Loss: 0.4436, Val loss: 0.4189
# Epoch 51, Train Loss: 0.4570, Val loss: 0.4107
# Epoch 52, Train Loss: 0.4425, Val loss: 0.4215
# Epoch 53, Train Loss: 0.4379, Val loss: 0.4118
# Epoch 54, Train Loss: 0.4515, Val loss: 0.4215
# Epoch 55, Train Loss: 0.4403, Val loss: 0.4048
# Epoch 56, Train Loss: 0.4366, Val loss: 0.4096
# Epoch 57, Train Loss: 0.4462, Val loss: 0.4204
# Epoch 58, Train Loss: 0.4393, Val loss: 0.4219
# Epoch 59, Train Loss: 0.4492, Val loss: 0.4096
# Epoch 60, Train Loss: 0.4488, Val loss: 0.4085
# Epoch 61, Train Loss: 0.4340, Val loss: 0.4041
# Epoch 62, Train Loss: 0.4334, Val loss: 0.4217
# Epoch 63, Train Loss: 0.4369, Val loss: 0.4200
# Epoch 64, Train Loss: 0.4352, Val loss: 0.4185
# Epoch 65, Train Loss: 0.4357, Val loss: 0.4148
# Epoch 66, Train Loss: 0.4315, Val loss: 0.4096
# Epoch 67, Train Loss: 0.4336, Val loss: 0.4059
# Epoch 68, Train Loss: 0.4335, Val loss: 0.4102
# Epoch 69, Train Loss: 0.4317, Val loss: 0.4019
# Epoch 70, Train Loss: 0.4358, Val loss: 0.4225
# Epoch 71, Train Loss: 0.4332, Val loss: 0.4078
# Epoch 72, Train Loss: 0.4345, Val loss: 0.4081
# Epoch 73, Train Loss: 0.4317, Val loss: 0.4256
# Epoch 74, Train Loss: 0.4310, Val loss: 0.3990
# Epoch 75, Train Loss: 0.4333, Val loss: 0.4198
# Epoch 76, Train Loss: 0.4321, Val loss: 0.4252
# Epoch 77, Train Loss: 0.4452, Val loss: 0.4095
# Epoch 78, Train Loss: 0.4435, Val loss: 0.3998
# Epoch 79, Train Loss: 0.4363, Val loss: 0.4240
# Epoch 80, Train Loss: 0.4365, Val loss: 0.4209
# Epoch 81, Train Loss: 0.4263, Val loss: 0.4037
# Epoch 82, Train Loss: 0.4284, Val loss: 0.4126
# Epoch 83, Train Loss: 0.4283, Val loss: 0.4216
# Epoch 84, Train Loss: 0.4272, Val loss: 0.4026
# Epoch 85, Train Loss: 0.4256, Val loss: 0.4001
# Epoch 86, Train Loss: 0.4251, Val loss: 0.4023
# Epoch 87, Train Loss: 0.4287, Val loss: 0.4159
# Epoch 88, Train Loss: 0.4413, Val loss: 0.4166
# Epoch 89, Train Loss: 0.4279, Val loss: 0.4139
# Epoch 90, Train Loss: 0.4276, Val loss: 0.4259
# Epoch 91, Train Loss: 0.4274, Val loss: 0.4191
# Epoch 92, Train Loss: 0.4313, Val loss: 0.4164
# Epoch 93, Train Loss: 0.4277, Val loss: 0.4024
# Epoch 94, Train Loss: 0.4250, Val loss: 0.4013
# Epoch 95, Train Loss: 0.4276, Val loss: 0.4076
# Epoch 96, Train Loss: 0.4223, Val loss: 0.4037
# Epoch 97, Train Loss: 0.4248, Val loss: 0.3940
# Epoch 98, Train Loss: 0.4236, Val loss: 0.4091
# Epoch 99, Train Loss: 0.4236, Val loss: 0.4019
# Epoch 100, Train Loss: 0.4420, Val loss: 0.4486
# Epoch 101, Train Loss: 0.4201, Val loss: 0.4011
# Epoch 102, Train Loss: 0.4396, Val loss: 0.4101
# Epoch 103, Train Loss: 0.4285, Val loss: 0.4014
# Epoch 104, Train Loss: 0.4396, Val loss: 0.4228
# Epoch 105, Train Loss: 0.4251, Val loss: 0.4187
# Epoch 106, Train Loss: 0.4307, Val loss: 0.3961
# Epoch 107, Train Loss: 0.4229, Val loss: 0.3977
# Epoch 108, Train Loss: 0.4176, Val loss: 0.4299
# Epoch 109, Train Loss: 0.4205, Val loss: 0.4148
# Epoch 110, Train Loss: 0.4243, Val loss: 0.4192
# Epoch 111, Train Loss: 0.4224, Val loss: 0.4094
# Epoch 112, Train Loss: 0.4235, Val loss: 0.3999
# Epoch 113, Train Loss: 0.4219, Val loss: 0.4123
# Epoch 114, Train Loss: 0.4204, Val loss: 0.4117
# Epoch 115, Train Loss: 0.4179, Val loss: 0.3896
# Epoch 116, Train Loss: 0.4177, Val loss: 0.4119
# Epoch 117, Train Loss: 0.4158, Val loss: 0.3959
# Epoch 118, Train Loss: 0.4177, Val loss: 0.4041
# Epoch 119, Train Loss: 0.4199, Val loss: 0.4185
# Epoch 120, Train Loss: 0.4330, Val loss: 0.4414
# Epoch 121, Train Loss: 0.4225, Val loss: 0.4198
# Epoch 122, Train Loss: 0.4267, Val loss: 0.4122
# Epoch 123, Train Loss: 0.4325, Val loss: 0.4063
# Epoch 124, Train Loss: 0.4207, Val loss: 0.4174
# Epoch 125, Train Loss: 0.4238, Val loss: 0.4055
# Epoch 126, Train Loss: 0.4185, Val loss: 0.4226
# Epoch 127, Train Loss: 0.4210, Val loss: 0.4144
# Epoch 128, Train Loss: 0.4150, Val loss: 0.4123
# Epoch 129, Train Loss: 0.4159, Val loss: 0.4122
# Epoch 130, Train Loss: 0.4165, Val loss: 0.4043
# Epoch 131, Train Loss: 0.4193, Val loss: 0.3901
# Epoch 132, Train Loss: 0.4180, Val loss: 0.4026
# Epoch 133, Train Loss: 0.4282, Val loss: 0.3949
# Epoch 134, Train Loss: 0.4289, Val loss: 0.4019
# Epoch 135, Train Loss: 0.4307, Val loss: 0.4337
# Epoch 136, Train Loss: 0.4235, Val loss: 0.4025
# Epoch 137, Train Loss: 0.4173, Val loss: 0.4064
# Epoch 138, Train Loss: 0.4143, Val loss: 0.4048
# Epoch 139, Train Loss: 0.4225, Val loss: 0.3974
# Epoch 140, Train Loss: 0.4144, Val loss: 0.4012
# Epoch 141, Train Loss: 0.4155, Val loss: 0.3953
# Epoch 142, Train Loss: 0.4168, Val loss: 0.4199
# Epoch 143, Train Loss: 0.4171, Val loss: 0.4029
# Epoch 144, Train Loss: 0.4291, Val loss: 0.4192
# Epoch 145, Train Loss: 0.4137, Val loss: 0.3863
# Epoch 146, Train Loss: 0.4309, Val loss: 0.3950
# Epoch 147, Train Loss: 0.4123, Val loss: 0.4184
# Epoch 148, Train Loss: 0.4187, Val loss: 0.4110
# Epoch 149, Train Loss: 0.4152, Val loss: 0.3962
# Epoch 150, Train Loss: 0.4143, Val loss: 0.3990
# Epoch 151, Train Loss: 0.4142, Val loss: 0.3917
# Epoch 152, Train Loss: 0.4124, Val loss: 0.3960
# Epoch 153, Train Loss: 0.4131, Val loss: 0.3991
# Epoch 154, Train Loss: 0.4135, Val loss: 0.4266
# Epoch 155, Train Loss: 0.4119, Val loss: 0.4084
# Epoch 156, Train Loss: 0.4266, Val loss: 0.4064
# Epoch 157, Train Loss: 0.4163, Val loss: 0.4074
# Epoch 158, Train Loss: 0.4142, Val loss: 0.3940
# Epoch 159, Train Loss: 0.4221, Val loss: 0.4016
# Epoch 160, Train Loss: 0.4147, Val loss: 0.3939
# Epoch 161, Train Loss: 0.4116, Val loss: 0.3972
# Epoch 162, Train Loss: 0.4148, Val loss: 0.4005
# Epoch 163, Train Loss: 0.4147, Val loss: 0.3966
# Epoch 164, Train Loss: 0.4170, Val loss: 0.4073
# Epoch 165, Train Loss: 0.4120, Val loss: 0.4332
# Epoch 166, Train Loss: 0.4153, Val loss: 0.4087
# Epoch 167, Train Loss: 0.4099, Val loss: 0.3975
# Epoch 168, Train Loss: 0.4311, Val loss: 0.4060
# Epoch 169, Train Loss: 0.4139, Val loss: 0.4117
# Epoch 170, Train Loss: 0.4129, Val loss: 0.4025
# Epoch 171, Train Loss: 0.4170, Val loss: 0.3984
# Epoch 172, Train Loss: 0.4106, Val loss: 0.3903
# Epoch 173, Train Loss: 0.4096, Val loss: 0.3853
# Epoch 174, Train Loss: 0.4124, Val loss: 0.3965
# Epoch 175, Train Loss: 0.4109, Val loss: 0.3930
# Epoch 176, Train Loss: 0.4121, Val loss: 0.4049
# Epoch 177, Train Loss: 0.4286, Val loss: 0.4098
# Epoch 178, Train Loss: 0.4158, Val loss: 0.4278
# Epoch 179, Train Loss: 0.4103, Val loss: 0.4015
# Epoch 180, Train Loss: 0.4205, Val loss: 0.4021
# Epoch 181, Train Loss: 0.4192, Val loss: 0.3904
# Epoch 182, Train Loss: 0.4158, Val loss: 0.4041
# Epoch 183, Train Loss: 0.4202, Val loss: 0.4154
# Epoch 184, Train Loss: 0.4226, Val loss: 0.3951
# Epoch 185, Train Loss: 0.4110, Val loss: 0.3859
# Epoch 186, Train Loss: 0.4108, Val loss: 0.4147
# Epoch 187, Train Loss: 0.4086, Val loss: 0.4080
# Epoch 188, Train Loss: 0.4109, Val loss: 0.3996
# Epoch 189, Train Loss: 0.4133, Val loss: 0.3932
# Epoch 190, Train Loss: 0.4116, Val loss: 0.3931
# Epoch 191, Train Loss: 0.4220, Val loss: 0.4194
# Epoch 192, Train Loss: 0.4119, Val loss: 0.3953
# Epoch 193, Train Loss: 0.4096, Val loss: 0.4059
# Epoch 194, Train Loss: 0.4123, Val loss: 0.4167
# Epoch 195, Train Loss: 0.4083, Val loss: 0.4295
# Epoch 196, Train Loss: 0.4113, Val loss: 0.3959
# Epoch 197, Train Loss: 0.4077, Val loss: 0.3955
# Epoch 198, Train Loss: 0.4111, Val loss: 0.4629
# Epoch 199, Train Loss: 0.4161, Val loss: 0.4157
# Epoch 200, Train Loss: 0.4200, Val loss: 0.4154
# Epoch 201, Train Loss: 0.4132, Val loss: 0.3966
# Epoch 202, Train Loss: 0.4098, Val loss: 0.4052
# Epoch 203, Train Loss: 0.4084, Val loss: 0.4324
# Epoch 204, Train Loss: 0.4115, Val loss: 0.4126
# Epoch 205, Train Loss: 0.4195, Val loss: 0.3939
# Epoch 206, Train Loss: 0.4111, Val loss: 0.3981
# Epoch 207, Train Loss: 0.4108, Val loss: 0.4090
# Epoch 208, Train Loss: 0.4065, Val loss: 0.4054
# Epoch 209, Train Loss: 0.4088, Val loss: 0.3938
# Epoch 210, Train Loss: 0.4101, Val loss: 0.4150
# Epoch 211, Train Loss: 0.4093, Val loss: 0.4000
# Epoch 212, Train Loss: 0.4192, Val loss: 0.3925
# Epoch 213, Train Loss: 0.4090, Val loss: 0.3946
# Epoch 214, Train Loss: 0.4057, Val loss: 0.4007
# Epoch 215, Train Loss: 0.4102, Val loss: 0.4059
# Epoch 216, Train Loss: 0.4071, Val loss: 0.4312
# Epoch 217, Train Loss: 0.4071, Val loss: 0.3911
# Epoch 218, Train Loss: 0.4068, Val loss: 0.3995
# Epoch 219, Train Loss: 0.4217, Val loss: 0.4046
# Epoch 220, Train Loss: 0.4163, Val loss: 0.4005
# Epoch 221, Train Loss: 0.4091, Val loss: 0.4166
# Epoch 222, Train Loss: 0.4098, Val loss: 0.4004
# Epoch 223, Train Loss: 0.4058, Val loss: 0.4076
# Epoch 224, Train Loss: 0.4212, Val loss: 0.3949
# Epoch 225, Train Loss: 0.4142, Val loss: 0.3960
# Epoch 226, Train Loss: 0.4082, Val loss: 0.4308
# Epoch 227, Train Loss: 0.4073, Val loss: 0.3956
# Epoch 228, Train Loss: 0.4039, Val loss: 0.4109
# Epoch 229, Train Loss: 0.4023, Val loss: 0.4073
# Epoch 230, Train Loss: 0.4071, Val loss: 0.4049
# Epoch 231, Train Loss: 0.4051, Val loss: 0.4058
# Epoch 232, Train Loss: 0.4061, Val loss: 0.3941
# Epoch 233, Train Loss: 0.4078, Val loss: 0.4048
# Epoch 234, Train Loss: 0.4076, Val loss: 0.4106
# Epoch 235, Train Loss: 0.4072, Val loss: 0.4156
# Epoch 236, Train Loss: 0.4072, Val loss: 0.4197
# Epoch 237, Train Loss: 0.4042, Val loss: 0.4132
# Epoch 238, Train Loss: 0.4130, Val loss: 0.4039
# Epoch 239, Train Loss: 0.4067, Val loss: 0.4032
# Epoch 240, Train Loss: 0.4071, Val loss: 0.4231
# Epoch 241, Train Loss: 0.4050, Val loss: 0.4054
# Epoch 242, Train Loss: 0.4311, Val loss: 0.4085
# Epoch 243, Train Loss: 0.4084, Val loss: 0.4036
# Epoch 244, Train Loss: 0.4072, Val loss: 0.3901
# Epoch 245, Train Loss: 0.4053, Val loss: 0.3949
# Epoch 246, Train Loss: 0.4073, Val loss: 0.3905
# Epoch 247, Train Loss: 0.4058, Val loss: 0.3898
# Epoch 248, Train Loss: 0.4037, Val loss: 0.4175
# Epoch 249, Train Loss: 0.4290, Val loss: 0.4093
# Epoch 250, Train Loss: 0.4249, Val loss: 0.4074
# Epoch 251, Train Loss: 0.4092, Val loss: 0.4027
# Epoch 252, Train Loss: 0.4066, Val loss: 0.3893
# Epoch 253, Train Loss: 0.4119, Val loss: 0.4035
# Epoch 254, Train Loss: 0.4109, Val loss: 0.4120
# Epoch 255, Train Loss: 0.4044, Val loss: 0.4197
# Epoch 256, Train Loss: 0.4072, Val loss: 0.4063
# Epoch 257, Train Loss: 0.4050, Val loss: 0.3970
# Epoch 258, Train Loss: 0.4197, Val loss: 0.4039
# Epoch 259, Train Loss: 0.4052, Val loss: 0.3985
# Epoch 260, Train Loss: 0.4061, Val loss: 0.4132
# Epoch 261, Train Loss: 0.4072, Val loss: 0.4198
# Epoch 262, Train Loss: 0.4045, Val loss: 0.4150
# Epoch 263, Train Loss: 0.4050, Val loss: 0.4043
# Epoch 264, Train Loss: 0.4065, Val loss: 0.4034
# Epoch 265, Train Loss: 0.4133, Val loss: 0.4116
# Epoch 266, Train Loss: 0.4062, Val loss: 0.3993
# Epoch 267, Train Loss: 0.4099, Val loss: 0.4129
# Epoch 268, Train Loss: 0.4018, Val loss: 0.4101
# Epoch 269, Train Loss: 0.4103, Val loss: 0.4068
# Epoch 270, Train Loss: 0.4058, Val loss: 0.3955
# Epoch 271, Train Loss: 0.4032, Val loss: 0.4134
# Epoch 272, Train Loss: 0.4030, Val loss: 0.4184
# Epoch 273, Train Loss: 0.4072, Val loss: 0.3948
# Epoch 274, Train Loss: 0.4050, Val loss: 0.3969
# Epoch 275, Train Loss: 0.4020, Val loss: 0.4149
# Epoch 276, Train Loss: 0.4076, Val loss: 0.4042
# Epoch 277, Train Loss: 0.4045, Val loss: 0.4148
# Epoch 278, Train Loss: 0.4035, Val loss: 0.4122
# Epoch 279, Train Loss: 0.4015, Val loss: 0.4096
# Epoch 280, Train Loss: 0.4042, Val loss: 0.4087
# Epoch 281, Train Loss: 0.4087, Val loss: 0.4062
# Epoch 282, Train Loss: 0.4148, Val loss: 0.3890
# Epoch 283, Train Loss: 0.4059, Val loss: 0.4078
# Epoch 284, Train Loss: 0.4107, Val loss: 0.3948
# Epoch 285, Train Loss: 0.4057, Val loss: 0.4257
# Epoch 286, Train Loss: 0.4057, Val loss: 0.4079
# Epoch 287, Train Loss: 0.4065, Val loss: 0.4098
# Epoch 288, Train Loss: 0.4177, Val loss: 0.4031
# Epoch 289, Train Loss: 0.4033, Val loss: 0.3931
# Epoch 290, Train Loss: 0.4039, Val loss: 0.4013
# Epoch 291, Train Loss: 0.4033, Val loss: 0.3973
# Epoch 292, Train Loss: 0.4122, Val loss: 0.4037
# Epoch 293, Train Loss: 0.4066, Val loss: 0.4023
# Epoch 294, Train Loss: 0.4041, Val loss: 0.4037
# Epoch 295, Train Loss: 0.4047, Val loss: 0.3997
# Epoch 296, Train Loss: 0.4003, Val loss: 0.3856
# Epoch 297, Train Loss: 0.4050, Val loss: 0.4143
# Epoch 298, Train Loss: 0.4040, Val loss: 0.4081
# Epoch 299, Train Loss: 0.4086, Val loss: 0.3906
# Epoch 300, Train Loss: 0.4037, Val loss: 0.3890
# Epoch 301, Train Loss: 0.4009, Val loss: 0.3995
# Epoch 302, Train Loss: 0.4021, Val loss: 0.4079
# Epoch 303, Train Loss: 0.4025, Val loss: 0.4093
# Epoch 304, Train Loss: 0.4079, Val loss: 0.4081
# Epoch 305, Train Loss: 0.4049, Val loss: 0.4622
# Epoch 306, Train Loss: 0.4161, Val loss: 0.4031
# Epoch 307, Train Loss: 0.3988, Val loss: 0.4121
# Epoch 308, Train Loss: 0.4095, Val loss: 0.4160
# Epoch 309, Train Loss: 0.4030, Val loss: 0.4041
# Epoch 310, Train Loss: 0.4032, Val loss: 0.4027
# Epoch 311, Train Loss: 0.4012, Val loss: 0.4088
# Epoch 312, Train Loss: 0.4060, Val loss: 0.4087
# Epoch 313, Train Loss: 0.4125, Val loss: 0.3963
# Epoch 314, Train Loss: 0.4011, Val loss: 0.3893
# Epoch 315, Train Loss: 0.4054, Val loss: 0.3935
# Epoch 316, Train Loss: 0.4073, Val loss: 0.4018
# Epoch 317, Train Loss: 0.4028, Val loss: 0.4217
# Epoch 318, Train Loss: 0.4022, Val loss: 0.4101
# Epoch 319, Train Loss: 0.4063, Val loss: 0.4018
# Epoch 320, Train Loss: 0.4030, Val loss: 0.4132
# Epoch 321, Train Loss: 0.4019, Val loss: 0.4045
# Epoch 322, Train Loss: 0.4106, Val loss: 0.4085
# Epoch 323, Train Loss: 0.4016, Val loss: 0.4041
# Epoch 324, Train Loss: 0.4033, Val loss: 0.4122
# Epoch 325, Train Loss: 0.4016, Val loss: 0.3959
# Epoch 326, Train Loss: 0.4020, Val loss: 0.3924
# Epoch 327, Train Loss: 0.4009, Val loss: 0.4083
# Epoch 328, Train Loss: 0.4068, Val loss: 0.3973
# Epoch 329, Train Loss: 0.4026, Val loss: 0.3999
# Epoch 330, Train Loss: 0.4018, Val loss: 0.4077
# Epoch 331, Train Loss: 0.4031, Val loss: 0.3983
# Epoch 332, Train Loss: 0.4029, Val loss: 0.4642
# Epoch 333, Train Loss: 0.4001, Val loss: 0.3911
# Epoch 334, Train Loss: 0.4003, Val loss: 0.4046
# Epoch 335, Train Loss: 0.4017, Val loss: 0.4004
# Epoch 336, Train Loss: 0.4050, Val loss: 0.4147
# Epoch 337, Train Loss: 0.4026, Val loss: 0.3929
# Epoch 338, Train Loss: 0.3986, Val loss: 0.4024
# Epoch 339, Train Loss: 0.4133, Val loss: 0.3976
# Epoch 340, Train Loss: 0.4241, Val loss: 0.4305
# Epoch 341, Train Loss: 0.4012, Val loss: 0.4091
# Epoch 342, Train Loss: 0.4022, Val loss: 0.3921
# Epoch 343, Train Loss: 0.4161, Val loss: 0.4049
# Epoch 344, Train Loss: 0.4049, Val loss: 0.3958
# Epoch 345, Train Loss: 0.3996, Val loss: 0.3930
# Epoch 346, Train Loss: 0.3982, Val loss: 0.4144
# Epoch 347, Train Loss: 0.4008, Val loss: 0.3932
# Epoch 348, Train Loss: 0.3981, Val loss: 0.3908
# Epoch 349, Train Loss: 0.4012, Val loss: 0.4105
# Epoch 350, Train Loss: 0.3999, Val loss: 0.4112
# Epoch 351, Train Loss: 0.4000, Val loss: 0.4036
# Epoch 352, Train Loss: 0.4009, Val loss: 0.3951
# Epoch 353, Train Loss: 0.4018, Val loss: 0.4104
# Epoch 354, Train Loss: 0.4011, Val loss: 0.4170
# Epoch 355, Train Loss: 0.4008, Val loss: 0.4444
# Epoch 356, Train Loss: 0.4095, Val loss: 0.4112
# Epoch 357, Train Loss: 0.4022, Val loss: 0.4058
# Epoch 358, Train Loss: 0.3998, Val loss: 0.4376
# Epoch 359, Train Loss: 0.4039, Val loss: 0.4105
# Epoch 360, Train Loss: 0.4009, Val loss: 0.4004
# Epoch 361, Train Loss: 0.4012, Val loss: 0.4104
# Epoch 362, Train Loss: 0.4006, Val loss: 0.4000
# Epoch 363, Train Loss: 0.4006, Val loss: 0.4433
# Epoch 364, Train Loss: 0.3991, Val loss: 0.3899
# Epoch 365, Train Loss: 0.4091, Val loss: 0.4006
# Epoch 366, Train Loss: 0.4031, Val loss: 0.4018
# Epoch 367, Train Loss: 0.4043, Val loss: 0.3957
# Epoch 368, Train Loss: 0.4017, Val loss: 0.4090
# Epoch 369, Train Loss: 0.4005, Val loss: 0.4072
# Epoch 370, Train Loss: 0.4016, Val loss: 0.4060
# Epoch 371, Train Loss: 0.3998, Val loss: 0.4060
# Epoch 372, Train Loss: 0.4004, Val loss: 0.3942
# Epoch 373, Train Loss: 0.3994, Val loss: 0.4070
# Epoch 374, Train Loss: 0.3964, Val loss: 0.3997
# Epoch 375, Train Loss: 0.4085, Val loss: 0.3987
# Epoch 376, Train Loss: 0.4010, Val loss: 0.4158
# Epoch 377, Train Loss: 0.4000, Val loss: 0.3928
# Epoch 378, Train Loss: 0.3998, Val loss: 0.4195
# Epoch 379, Train Loss: 0.4019, Val loss: 0.4123
# Epoch 380, Train Loss: 0.4004, Val loss: 0.4043
# Epoch 381, Train Loss: 0.3989, Val loss: 0.3993
# Epoch 382, Train Loss: 0.4015, Val loss: 0.3940
# Epoch 383, Train Loss: 0.4038, Val loss: 0.4076
# Epoch 384, Train Loss: 0.4014, Val loss: 0.3975
# Epoch 385, Train Loss: 0.4039, Val loss: 0.4046
# Epoch 386, Train Loss: 0.4012, Val loss: 0.4002
# Epoch 387, Train Loss: 0.4020, Val loss: 0.4019
# Epoch 388, Train Loss: 0.3990, Val loss: 0.3883
# Epoch 389, Train Loss: 0.3973, Val loss: 0.4061
# Epoch 390, Train Loss: 0.4132, Val loss: 0.3990
# Epoch 391, Train Loss: 0.4006, Val loss: 0.4093
# Epoch 392, Train Loss: 0.3972, Val loss: 0.3985
# Epoch 393, Train Loss: 0.3987, Val loss: 0.3973
# Epoch 394, Train Loss: 0.3965, Val loss: 0.3929
# Epoch 395, Train Loss: 0.3984, Val loss: 0.4180
# Epoch 396, Train Loss: 0.4002, Val loss: 0.4079
# Epoch 397, Train Loss: 0.3989, Val loss: 0.4074
# Epoch 398, Train Loss: 0.3956, Val loss: 0.3928
# Epoch 399, Train Loss: 0.4003, Val loss: 0.3911
# Epoch 400, Train Loss: 0.4021, Val loss: 0.4110
# Epoch 401, Train Loss: 0.3996, Val loss: 0.3872
# Epoch 402, Train Loss: 0.4117, Val loss: 0.4046
# Epoch 403, Train Loss: 0.3980, Val loss: 0.4069
# Epoch 404, Train Loss: 0.4015, Val loss: 0.4054
# Epoch 405, Train Loss: 0.3990, Val loss: 0.4076
# Epoch 406, Train Loss: 0.4003, Val loss: 0.4015
# Epoch 407, Train Loss: 0.3987, Val loss: 0.4148
# Epoch 408, Train Loss: 0.3993, Val loss: 0.4075
# Epoch 409, Train Loss: 0.3954, Val loss: 0.4078
# Epoch 410, Train Loss: 0.4032, Val loss: 0.3986
# Epoch 411, Train Loss: 0.4036, Val loss: 0.4326
# Epoch 412, Train Loss: 0.3995, Val loss: 0.4105
# Epoch 413, Train Loss: 0.3938, Val loss: 0.3953
# Epoch 414, Train Loss: 0.3993, Val loss: 0.3942
# Epoch 415, Train Loss: 0.3975, Val loss: 0.4099
# Epoch 416, Train Loss: 0.4016, Val loss: 0.4067
# Epoch 417, Train Loss: 0.4035, Val loss: 0.4227
# Epoch 418, Train Loss: 0.3971, Val loss: 0.3881
# Epoch 419, Train Loss: 0.3957, Val loss: 0.4038
# Epoch 420, Train Loss: 0.3956, Val loss: 0.3948
# Epoch 421, Train Loss: 0.3976, Val loss: 0.3925
# Epoch 422, Train Loss: 0.4096, Val loss: 0.3959
# Epoch 423, Train Loss: 0.3973, Val loss: 0.3864
# Epoch 424, Train Loss: 0.3956, Val loss: 0.3941
# Epoch 425, Train Loss: 0.4023, Val loss: 0.4110
# Epoch 426, Train Loss: 0.3989, Val loss: 0.4120
# Epoch 427, Train Loss: 0.3982, Val loss: 0.3943
# Epoch 428, Train Loss: 0.3967, Val loss: 0.4060
# Epoch 429, Train Loss: 0.4056, Val loss: 0.3957
# Epoch 430, Train Loss: 0.3974, Val loss: 0.4054
# Epoch 431, Train Loss: 0.3988, Val loss: 0.4067
# Epoch 432, Train Loss: 0.4028, Val loss: 0.3892
# Epoch 433, Train Loss: 0.4140, Val loss: 0.4065
# Epoch 434, Train Loss: 0.3951, Val loss: 0.3982
# Epoch 435, Train Loss: 0.4004, Val loss: 0.4000
# Epoch 436, Train Loss: 0.4001, Val loss: 0.3909
# Epoch 437, Train Loss: 0.3962, Val loss: 0.4024
# Epoch 438, Train Loss: 0.3980, Val loss: 0.4008
# Epoch 439, Train Loss: 0.3996, Val loss: 0.4046
# Epoch 440, Train Loss: 0.4079, Val loss: 0.4154
# Epoch 441, Train Loss: 0.3985, Val loss: 0.4019
# Epoch 442, Train Loss: 0.4066, Val loss: 0.3976
# Epoch 443, Train Loss: 0.3955, Val loss: 0.3976
# Epoch 444, Train Loss: 0.3946, Val loss: 0.3987
# Epoch 445, Train Loss: 0.3941, Val loss: 0.4090
# Epoch 446, Train Loss: 0.3931, Val loss: 0.4128
# Epoch 447, Train Loss: 0.3958, Val loss: 0.4072
# Epoch 448, Train Loss: 0.3974, Val loss: 0.4094
# Epoch 449, Train Loss: 0.3991, Val loss: 0.3985
# Epoch 450, Train Loss: 0.3972, Val loss: 0.3909
# Epoch 451, Train Loss: 0.3969, Val loss: 0.3950
# Epoch 452, Train Loss: 0.3955, Val loss: 0.4009
# Epoch 453, Train Loss: 0.3972, Val loss: 0.4029
# Epoch 454, Train Loss: 0.3943, Val loss: 0.3939
# Epoch 455, Train Loss: 0.3985, Val loss: 0.4149
# Epoch 456, Train Loss: 0.4003, Val loss: 0.4175
# Epoch 457, Train Loss: 0.3983, Val loss: 0.4146
# Epoch 458, Train Loss: 0.4091, Val loss: 0.3950
# Epoch 459, Train Loss: 0.4026, Val loss: 0.4022
# Epoch 460, Train Loss: 0.4127, Val loss: 0.3964
# Epoch 461, Train Loss: 0.3982, Val loss: 0.4002
# Epoch 462, Train Loss: 0.4047, Val loss: 0.4138
# Epoch 463, Train Loss: 0.4033, Val loss: 0.4007
# Epoch 464, Train Loss: 0.3972, Val loss: 0.3937
# Epoch 465, Train Loss: 0.4235, Val loss: 0.3972
# Epoch 466, Train Loss: 0.3971, Val loss: 0.3971
# Epoch 467, Train Loss: 0.3968, Val loss: 0.4032
# Epoch 468, Train Loss: 0.3941, Val loss: 0.4426
# Epoch 469, Train Loss: 0.3940, Val loss: 0.4023
# Epoch 470, Train Loss: 0.3959, Val loss: 0.4064
# Epoch 471, Train Loss: 0.3935, Val loss: 0.3948
# Epoch 472, Train Loss: 0.3968, Val loss: 0.4127
# Epoch 473, Train Loss: 0.3957, Val loss: 0.3945
# Epoch 474, Train Loss: 0.4142, Val loss: 0.4085
# Epoch 475, Train Loss: 0.3988, Val loss: 0.4101
# Epoch 476, Train Loss: 0.3995, Val loss: 0.4041
# Epoch 477, Train Loss: 0.3963, Val loss: 0.3944
# Epoch 478, Train Loss: 0.3940, Val loss: 0.3974
# Epoch 479, Train Loss: 0.3996, Val loss: 0.4037
# Epoch 480, Train Loss: 0.3970, Val loss: 0.4063
# Epoch 481, Train Loss: 0.3951, Val loss: 0.4201
# Epoch 482, Train Loss: 0.3983, Val loss: 0.3910
# Epoch 483, Train Loss: 0.4084, Val loss: 0.3947
# Epoch 484, Train Loss: 0.3970, Val loss: 0.4013
# Epoch 485, Train Loss: 0.3953, Val loss: 0.4089
# Epoch 486, Train Loss: 0.3939, Val loss: 0.4510
# Epoch 487, Train Loss: 0.3973, Val loss: 0.3985
# Epoch 488, Train Loss: 0.4125, Val loss: 0.4000
# Epoch 489, Train Loss: 0.4076, Val loss: 0.3897
# Epoch 490, Train Loss: 0.3912, Val loss: 0.4084
# Epoch 491, Train Loss: 0.4028, Val loss: 0.4066
# Epoch 492, Train Loss: 0.3980, Val loss: 0.4020
# Epoch 493, Train Loss: 0.3970, Val loss: 0.3974
# Epoch 494, Train Loss: 0.3961, Val loss: 0.4023
# Epoch 495, Train Loss: 0.3985, Val loss: 0.4046
# Epoch 496, Train Loss: 0.3946, Val loss: 0.3925
# Epoch 497, Train Loss: 0.3931, Val loss: 0.3889
# Epoch 498, Train Loss: 0.3967, Val loss: 0.3991
# Epoch 499, Train Loss: 0.4024, Val loss: 0.4065
# Epoch 500, Train Loss: 0.3944, Val loss: 0.3946

# %%
#Visualizing the model performance
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.plot(range(1,len(train_losses)+1),train_losses,label="Training loss",color="Blue")
plt.plot(range(1,len(val_losses)+1),val_losses,label="Validation loss",color="Red")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation loss vs Epochs")
plt.legend()
plt.grid()
plt.show()

# %%
# Testing the model
model.eval()
predictions=[]
true_labels=[]
probablities=[]

with torch.no_grad():
    for batch in test_loader:
        batch=batch.to(device)
        out,_=model(batch)
        preds=torch.argmax(out,dim=1)  #Predictions
        probs=torch.softmax(out,dim=1) #Probablities
        
        predictions.append(preds.cpu())
        true_labels.append(batch.y.cpu())
        probablities.append(probs.cpu())
    
predictions=torch.cat(predictions)
true_labels=torch.cat(true_labels)
probablities=torch.cat(probablities)

# %% [markdown]
# ### Visualizing the performance of the model

# %% [markdown]
# #### Confusion matrix

# %%
# Confusion matrix
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import seaborn as sns
import matplotlib.pyplot as plt

cm=confusion_matrix(true_labels,predictions,normalize='true')

# %%
pid = {v: k for k, v in particle_ids.items()}
class_names=[pid[i] for i in range(len(pid))]

# %%
plt.figure(figsize=(8,6))

sns.heatmap(cm,
            annot=True,
            fmt='.2%',
            cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)

plt.xlabel("Predicted Particle")
plt.ylabel("True Particle")
plt.title("Confusion Matrix - Particle Identification")

plt.xticks(rotation=45)
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### ROC curve

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve,auc

#Here, we need to convert the labels to one-hot levels for ROC only
num_classes=3
y_true_bin=label_binarize(true_labels.numpy(),classes=range(num_classes))
y_score=probablities.numpy()

plt.figure(figsize=(8,6))

for i in range(num_classes):
    fpr, tpr,_=roc_curve(y_true_bin[:,i],y_score[:,i])
    roc_auc=auc(fpr,tpr)
    plt.plot(fpr,tpr,label=f'{class_names[i]}(AUC={roc_auc:.2f})')
plt.grid()
plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Multi-Class ROC Curves-GCN")
plt.legend()
plt.show()

# %% [markdown]
# #### Histograms
